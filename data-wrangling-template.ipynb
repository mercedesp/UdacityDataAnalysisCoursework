# %% [markdown]
# # Data Wrangling Template

# %% [markdown]
# ## Gather

# %%
import zipfile as zp
import pandas as pd

# %%
# Extract contents from zip folder
with zp.ZipFile('armenian-online-job-postings.zip','r') as myzip:
    myzip.extractall()

# %%
# Read CSV file into DataFrame
df = pd.read_csv('online-job-postings.csv')

# %% [markdown]
# ## Assess

# %%
df
# Out:
#                                                  jobpost          date  \
# 0      AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1      International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2      Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3      Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4      Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
# 5      Boutique "Appollo"\r\nJOB TITLE:  Saleswoman\r...  Jan 10, 2004
# 6      OSI Assistance Foundation - Armenian Branch Of...  Jan 11, 2004
# 7      International Research & Exchanges Board (IREX...  Jan 13, 2004
# 8      Yerevan Brandy Company \r\nJOB TITLE:  Assista...  Jan 13, 2004
# 9      American Embassy Yerevan\r\nANNOUNCEMENT NUMBE...  Jan 13, 2004
# 10     International Research & Exchanges Board (IREX...  Jan 13, 2004
# 11     International Research & Exchanges Board (IREX...  Jan 13, 2004
# ...

# %% [markdown]
# Problems with data:
# - Missing values (NaN)
# - Start Date has varying and inconsistent values (ex. ASAP/As soon as possible)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19001 entries, 0 to 19000
# Data columns (total 24 columns):
# jobpost             19001 non-null object
# date                19001 non-null object
# Title               18973 non-null object
# Company             18994 non-null object
# AnnouncementCode    1208 non-null object
# Term                7676 non-null object
# Eligibility         4930 non-null object
# Audience            640 non-null object
# StartDate           9675 non-null object
# Duration            10798 non-null object
# Location            18969 non-null object
# JobDescription      15109 non-null object
# JobRequirment       16479 non-null object
# RequiredQual        18517 non-null object
# Salary              9622 non-null object
# ApplicationP        18941 non-null object
# OpeningDate         18295 non-null object
# Deadline            18936 non-null object
# Notes               2211 non-null object
# AboutC              12470 non-null object
# ...

# %% [markdown]
# - Fix nondescriptive column headers and any typos in column name

# %%
# Display first five rows of the DataFrame using .head
df.head()
# Out:
#                                              jobpost          date  \
# 0  AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1  International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2  Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3  Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4  Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company AnnouncementCode Term  \
# 0             AMERIA Investment Consulting Company              NaN  NaN
# 1  International Research & Exchanges Board (IREX)              NaN  NaN
# ...

# %%
# Display the last five rows of the DataFrame using .tail
df.tail()
# Out:
#                                                  jobpost          date  \
# 18996  Technolinguistics NGO\r\n\r\n\r\nTITLE:  Senio...  Dec 28, 2015
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18998  "Coca-Cola Hellenic Bottling Company Armenia" ...  Dec 30, 2015
# 18999  San Lazzaro   LLC\r\n\r\n\r\nTITLE:  Head of O...  Dec 30, 2015
# 19000  "Kamurj" UCO CJSC\r\n\r\n\r\nTITLE:  Lawyer in...  Dec 30, 2015
#
#                                  Title  \
# 18996  Senior Creative UX/ UI Designer
# 18997     Category Development Manager
# 18998    Operational Marketing Manager
# 18999  Head of Online Sales Department
# 19000       Lawyer in Legal Department
#
#                                                  Company AnnouncementCode  \
# 18996                              Technolinguistics NGO              NaN
# 18997  "Coca-Cola Hellenic Bottling Company Armenia" ...              NaN
# ...

# %%
# Display the entry counts for the Year column using .value_counts
df['Year'].value_counts()
# Out:
# 2012    2149
# 2015    2009
# 2013    2009
# 2014    1983
# 2008    1785
# 2011    1697
# 2007    1538
# 2010    1511
# 2009    1191
# 2005    1138
# 2006    1116
# 2004     875
# Name: Year, dtype: int64

# %% [markdown]
# ## Clean
# #### Define
#
# - Select and replace all records in the StartDate column to ASAP (ie. replace any with "As soon as possible", "immediately" etc)
# - Select all column names that are not descriptive or spelled wrong and replace them with descriptive titles and fix the typos
#
# #### Code

# %%
df_clean = df.copy()

# %% [markdown]
# - Select all column names that are not descriptive or spelled wrong and replace them with descriptive titles and fix the typos
# - Nondescriptive and misspelled columen headers: ApplicationP, AboutC, RequiredQual, JobRequirment, jobpost, date
# - Replacement: ApplicationProcedure, AboutCompany, RequiredQualifications, JobRequirement, Jobpost, Date

# %%
df_clean = df_clean.rename(columns={'jobpost': 'Jobpost','date': 'Date', 'ApplicationP':'ApplicationProcedure', 
                                    'AboutC': 'AboutCompany', 'RequiredQual':'RequiredQualifications', 
                                    'JobRequirment': 'JobRequirement'})

# %%
df_clean.head(0)
# Out:
# Empty DataFrame
# Columns: [Jobpost, Date, Title, Company, AnnouncementCode, Term, Eligibility, Audience, StartDate, Duration, Location, JobDescription, JobRequirement, RequiredQualifications, Salary, ApplicationProcedure, OpeningDate, Deadline, Notes, AboutCompany, Attach, Year, Month, IT]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# - Select and replace all records in the StartDate column to ASAP (ie. replace any with "As soon as possible", "immediately" etc)

# %%
df_clean.StartDate.value_counts()
# Out:
# ASAP                                                                             4754
# Immediately                                                                       773
# As soon as possible                                                               543
# Upon hiring                                                                       261
# Immediate                                                                         259
# Immediate employment                                                              140
# As soon as possible.                                                               32
# 01 September 2012                                                                  31
# March 2006                                                                         27
# November 2006                                                                      22
# January 2010                                                                       19
# ...

# %%
len(df_clean.StartDate.value_counts())
# Out:
# 1186

# %%
pd.options.display.max_rows = 1200

# %%
df_clean.StartDate.value_counts()
# Out:
# ASAP                                                                                                                                                               4754
# Immediately                                                                                                                                                         773
# As soon as possible                                                                                                                                                 543
# Upon hiring                                                                                                                                                         261
# Immediate                                                                                                                                                           259
# ...

# %%
pd.options.display.max_rows = 50

# %% [markdown]
# - To make list of entries that are equivalent of 'ASAP' use a for loop to first make a list of all entries without the month present

# %% [markdown]
# #### Test
